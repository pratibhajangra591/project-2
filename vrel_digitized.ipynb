# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
import  vrel
from accretion import*


plt.loglog(vrel.z_arr, vrel.c_s_arr, 'C0')
plt.ylabel(r"$c_{s}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with $ 10\leq z \leq 1100$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arr
y = vrel.c_s_arr
x  = (x[0], x[1], x[2] )
y  = (y[0], y[1], y[2])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$c_{s}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is c_s(z<10) = (10**(-4.1193/np.log(10)))  * (z**0.9823)
# Out:
# Slope and intercept of fitting function = [ 0.98230927 -4.11931463]

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arr
y = vrel.c_s_arr
x  = (x[-3], x[-2], x[-1] )
y  = (y[-3], y[-2], y[-1])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$c_{s}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is c_s(z>1000) = (10**(-2.0570/np.log(10)))  * (z**0.5485)
# Out:
# Slope and intercept of fitting function = [ 0.54853505 -2.05703267]

# %%
 def c_s_extrapolation(variable):
    if variable < 10:
        m = 0.9823
        b = -4.1193/np.log(10)
        return   (z**m) * (10**b)
    elif  10 <= variable <= 1000:
        x = vrel.z_arr
        y = vrel.c_s_arr
        f = interpolate.interp1d(x, y , fill_value = "extrapolate")
        return f(variable)
    else:
        m =  0.5485
        b = -2.0570/np.log(10)
        return   (variable**m) * (10**b)
        

        
plt.figure(figsize = (8, 5))

z_arr = np.geomspace(1, 1e10, 100000)
cs_arr = np.zeros(len(z_arr))
for i, z in enumerate(z_arr):
    cs_arr[i] = c_s_extrapolation(z)
plt.loglog(z_arr, cs_arr, 'C0')   
plt.ylabel(r"$c_{s}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with extapolation for $z < 10$ and $z > 1000$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.loglog(vrel.z_rel_arr, vrel.v_rel_arr, 'C1')
plt.ylabel(r"$v_\mathrm{rel}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with $ 10\leq z \leq 1100$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_rel_arr
y = vrel.v_rel_arr
x  = (x[0], x[1], x[2] )
y  = (y[0], y[1], y[2])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{rel}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is v_rel(z<10) = (10**(-0.3375/np.log(10)))  * (z**0.4712)
# Out:
# Slope and intercept of fitting function = [ 0.47115605 -0.33749094]

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_rel_arr
y = vrel.v_rel_arr
x  = (x[-3], x[-2], x[-1] )
y  = (y[-3], y[-2], y[-1])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{rel}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is v_rel(z>1000) = (10**(4.3651/np.log(10)))  * (z**-0.4348)
# Out:
# Slope and intercept of fitting function = [-0.43475018  4.3650745 ]

# %%
def vrel_extrapolation(variable):
    if variable < 10:
        m = 0.4712
        b = -0.3375/np.log(10)
        return (variable**m) * (10**b)
    elif 10 <= variable <= 1000:
        x = vrel.z_rel_arr
        y = vrel.v_rel_arr
        f = interpolate.interp1d(x, y , fill_value = "extrapolate")
        return f(variable)
    else:
        m = -0.4348
        b = 4.3650/np.log(10)
        return (variable**m) * (10**b)
        

plt.figure(figsize = (8, 5))

z_arr = np.geomspace(1, 1e10, 100000)
v_rel_arr = np.zeros(len(z_arr))
for i, z in enumerate(z_arr):
    v_rel_arr[i] = vrel_extrapolation(z)
plt.loglog(z_arr, v_rel_arr, 'C2')   
plt.ylabel(r"$v_\mathrm{rel}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with extapolation for $z < 10$ and $z > 1000$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.loglog(vrel.z_arrA, vrel.v_effA_arr, 'C4')
plt.ylabel(r"$v_\mathrm{eff, \,\, A}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with $ 10\leq z \leq 1100$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arrA
y = vrel.v_effA_arr
x  = (x[0], x[1], x[2] )
y  = (y[0], y[1], y[2])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{eff,\,A}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 20)
plt.xlabel(r"$z+1$", fontsize = 20)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.show()

# So, the fitting function is v_effA (z< 10) = (10**(-1.9190/np.log(10)))  * (j0**0.7313)
# Out:
# Slope and intercept of fitting function = [ 0.73127503 -1.91903423]

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arrA
y = vrel.v_effA_arr
x  = (x[-3], x[-2], x[-1] )
y  = (y[-3], y[-2], y[-1])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{eff,\,A}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 20)
plt.xlabel(r"$z+1$", fontsize = 20)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.show()

# So, the fitting function is v_effA (z>1000) = (10**(-0.1793/np.log(10)))  * (j0**0.3039)
# Out:
# Slope and intercept of fitting function = [ 0.30389344 -0.17926566]

# %%
def veffA_extrapolation(variable):
    if variable < 10:
        m = 0.7313
        b = -1.9190/np.log(10)
        return (variable**m) * (10**b)
    elif 10 <= variable <= 1000:
        x = vrel.z_arrA
        y = vrel.v_effA_arr
        f = interpolate.interp1d(x, y , fill_value = "extrapolate")
        return f(variable)
    else:
        m = 0.3039
        b = -0.1793/np.log(10)
        return (variable**m) * (10**b)
        
        
plt.figure(figsize = (8, 5))

z_arr = np.geomspace(1, 1e10, 100000)
v_effA_arr = np.zeros(len(z_arr))
for i, z in enumerate(z_arr):
    v_effA_arr[i] = veffA_extrapolation(z)
plt.loglog(z_arr, v_effA_arr, 'C4')   
plt.ylabel(r"$v_\mathrm{eff,\, A}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with extapolation for $z < 10$ and $z > 1000$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.loglog(vrel.z_arrB, vrel.v_effB_arr, 'C5')
plt.ylabel(r"$v_\mathrm{eff, \,\, B}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with $ 10\leq z \leq 1100$', fontsize = 20, pad = 7)
plt.show()

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arrB
y = vrel.v_effB_arr
x  = (x[0], x[1], x[2] )
y  = (y[0], y[1], y[2])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{eff,\,B}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is v_effB(z<10) = (10**(-0.6707np.log(10)))  * (z**0.5308)
# Out:
# Slope and intercept of fitting function = [ 0.53075209 -0.67066668]

# %%
plt.figure(figsize = (12, 5))

x = vrel.z_arrB
y = vrel.v_effB_arr
x  = (x[-3], x[-2], x[-1] )
y  = (y[-3], y[-2], y[-1])

plt.loglog(x, y, 'gd',  label = 'data')

p = np.polyfit(np.log(x), np.log(y), 1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label = 'fit')
print("Slope and intercept of fitting function =", p) 
plt.ylabel(r"$v_\mathrm{eff,\,B}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 23)
plt.xlabel(r"$z+1$", fontsize = 23)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# So, the fitting function is v_effB(z>1000) = (10**(-0.2794/np.log(10)))  * (z**0.3185)
# Out:
# Slope and intercept of fitting function = [ 0.31851765 -0.27940675]

# %%
def veffB_extrapolation(variable):
    if  variable < 10:
        m = 0.5308
        b = -0.6707/np.log(10)
        return (variable**m) * (10**b)
    elif 10 <= variable <= 1000:
        x = vrel.z_arrB
        y = vrel.v_effB_arr
        f = interpolate.interp1d(x, y , fill_value = "extrapolate")
        return f(variable)
    else:
        m = 0.3185
        b = -0.2794/np.log(10)
        return (variable**m) * (10**b)
        

plt.figure(figsize = (8, 5))    
    
z_arr = np.geomspace(1, 1e10, 100000)
v_effB_arr = np.zeros(len(z_arr))
for i, z in enumerate(z_arr):
    v_effB_arr[i] = veffB_extrapolation(z)
plt.loglog(z_arr, v_effB_arr, 'C5')   
plt.ylabel(r"$v_\mathrm{eff,\, B}\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 20)
plt.xlabel(r"$z+1$", fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.title('Digitized with extapolation for $z < 10$ and $z > 1000$', fontsize = 20, pad = 7)
plt.show()

# %%
colors = ['C0', 'C1','C2','C3','C4', 'C5']
fig,ax = plt.subplots(1, figsize = (7, 6))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')



ax.loglog(vrel.z_rel_arr, vrel.v_rel_arr, 'k-.', linewidth = 0.9) 
ax.loglog(vrel.z_arrB, vrel.v_effB_arr, 'k--') 
ax.loglog(vrel.z_arrA, vrel.v_effA_arr, 'k') 
ax.loglog(vrel.z_arr, vrel.c_s_arr, 'k:')


 
ax.tick_params(axis='x', pad = 9.9)
ax.tick_params(axis='y', pad = 9.9)

plt.ylabel(r"Velocity$\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 24, labelpad = 8)
plt.xlabel(r"$z + 1$", fontsize = 24, labelpad = 8)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)


plt.legend(['$v_\mathrm{rel}$', '$v_\mathrm{eff,\, B}$', '$v_\mathrm{eff,\, A}$' , '$c_{s}$'], 
           prop = {'size':17}, loc = 'lower right', shadow = True, 
           title_fontsize = 17, facecolor = 'white', fontsize = 15)


plt.ylim(0.5, 10)
plt.xlim(10, 1700)
plt.title('Digitized with $ 10\leq z \leq 1100$', fontsize = 20, pad = 7)
plt.savefig('velocity_digitized.pdf', bbox_inches = 'tight')
plt.show()

# %%
colors = ['C0', 'C1','C2','C3','C4', 'C5']
fig,ax = plt.subplots(1, figsize = (8.5, 6))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')


z_arr1 = np.geomspace(1, 1e10, 100000)
ax.loglog(z_arr1, v_rel_arr, 'k-.', linewidth = 0.9) 
ax.loglog(z_arr1, v_effB_arr, 'k--') 
ax.loglog(z_arr1, v_effA_arr, 'k') 
ax.loglog(z_arr1, cs_arr, 'k:')

 
ax.tick_params(axis='x', pad = 9.9)
ax.tick_params(axis='y', pad = 9.9)

plt.ylabel(r"Velocity$\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 24, labelpad = 8)
plt.xlabel(r"$z + 1$", fontsize = 24, labelpad = 8)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)


plt.legend(['$v_\mathrm{rel}$', '$v_\mathrm{eff,\, B}$', '$v_\mathrm{eff,\, A}$',  '$c_{s}$'], 
           prop = {'size':21}, loc = 'lower right', shadow = True, 
           title_fontsize = 17, facecolor = 'white', fontsize = 15)


plt.ylim(0.5, 10)
plt.xlim(10, 1700)
plt.title('Digitized with extapolation for $z < 10$ and $z > 1000$', fontsize = 21, pad = 7)
plt.savefig('velocity_digitized_extrapolated.pdf', bbox_inches = 'tight')
plt.show()

# %%
def c_s(z):
    β = 1.72
    z_dec = 130
    return  5.74 * np.sqrt((1+z)/1000) * (((((1+z_dec)/(1 + z))**β) + 1)**(-1/(2 * β))) 

def v_rel_digitized(z):
    return  vrel_extrapolation(z) 


def Mach_number(z):
        return v_rel_digitized(z)/c_s(z)

def v_eff_A(z):
    if Mach_number(z) > 1:
        return  c_s(z) * (((16/np.sqrt(2 * np.pi)) * (Mach_number(z)**3))**(1/6))  
    else:
        return  c_s(z) * np.sqrt(1 + (Mach_number(z)**2))


def v_eff_B(z):
    e = 2.71828
    if Mach_number(z) > 1:
        return  c_s(z) * Mach_number(z) * ((np.sqrt(2/np.pi) * np.log((2/e) * Mach_number(z)))**(-1/3))  
    else:
        return  c_s(z) * np.sqrt(1 + (Mach_number(z)**2))



def c_s_digitized(z):
    return  c_s_extrapolation(z)


def v_effA_digitized(z):
    return  veffA_extrapolation(z) 


def v_effB_digitized(z):
    return  veffB_extrapolation(z) 



colors = ['C0', 'C1','C2','C3','C4', 'C5']
fig,ax = plt.subplots(1, figsize = (8, 6))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 4, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 9, direction = 'in')


z_array = np.geomspace(1, 1e10, 100000)
cs_array = np.zeros(len(z_array))
v_effA_array = np.zeros(len(z_array))
v_effB_array = np.zeros(len(z_array))

cs_digitized_array = np.zeros(len(z_array))
v_effA_digitized_array = np.zeros(len(z_array))
v_effB_digitized_array = np.zeros(len(z_array))

v_rel_analytic_array = np.zeros(len(z_array))

for i, z in enumerate(z_array):
    cs_array[i] = c_s(z) 
    v_effA_array[i] = v_eff_A(z) 
    v_effB_array[i] = v_eff_B(z) 
    cs_digitized_array[i] = c_s_digitized(z)
    v_effA_digitized_array[i] = v_effA_digitized(z)
    v_effB_digitized_array[i] = v_effB_digitized(z)

    v_rel_analytic_array[i] = v_rel_digitized(z)
    

ax.loglog(z_array, v_effB_array, 'C2')
ax.loglog(z_array, v_effA_array, 'C1')
ax.loglog(z_array, cs_array, 'C0')

ax.loglog(z_array, v_effB_digitized_array, 'C2', ls = '--')
ax.loglog(z_array, v_effA_digitized_array, 'C1', ls = '--')
ax.loglog(z_array, cs_digitized_array, 'C0', ls = '--')

ax.loglog(z_array, v_rel_analytic_array, 'k', ls = '-.') 
ax.tick_params(axis='x', pad = 9.9)
ax.tick_params(axis='y', pad = 9.9)


plt.ylim(0.5, 10)
plt.xlim(10, 1700)

lines = ax.get_lines()
legend1 = plt.legend([lines[i] for i in [0, 1, 2]], [ r'$v_\mathrm{eff, \, B} $', r'$v_\mathrm{eff, \, A}$', '$c_{s}$'],
           title_fontsize = 12, loc = 'lower right', prop = {"size":18.5})
legend2 = plt.legend([lines[i] for i in [0, 3]], ['Analytic', r'Digitized'],
           title_fontsize = 12, loc = (0.74, 0.33), prop = {"size":15})

ax.add_artist(legend1)
ax.add_artist(legend2)

plt.text(12, 2.8, '$v_\mathrm{rel,\, digitized}$', fontsize = 24, rotation = 30)

plt.ylabel(r"Velocity$\, \mathrm{[km \,s^{-1}}]$ ", fontsize = 24, labelpad = 8)
plt.xlabel(r"$z + 1$", fontsize = 24, labelpad = 8)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)
plt.savefig('velocity_analytic_vs_digitized_extrapolated.pdf', bbox_inches = 'tight')
plt.show()
# Out:
# /tmp/ipykernel_34988/3811799770.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   return  c_s(z) * Mach_number(z) * ((np.sqrt(2/np.pi) * np.log((2/e) * Mach_number(z)))**(-1/3))
