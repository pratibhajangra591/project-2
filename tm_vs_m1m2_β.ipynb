# %%
# Final merger time for the reference systems with masses m_1 = 1e5 M_solar
# and m_2 = 1 M_solar, as a function of the initial 
# angular momentum j0 for binaries having Power Law PDF (1-1e5) for PBHs having alpha-disk 
# with dynamical friction (Ostriker) as dissipative force.

# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import math
from matplotlib import rcParams
import matplotlib.pyplot as plt
from matplotlib.ticker import LogFormatterExponent
from matplotlib.colors import LogNorm
from matplotlib import ticker, cm
from accretion import *
import matplotlib as mpl
from matplotlib.lines import Line2D
from scipy.interpolate import interp1d
from scipy.integrate import quad
from scipy.special import gamma
import mass_function
from imripy import halo, constants as c, merger_system as ms, inspiral, waveform, detector, plot_utils
from imripy.inspiral import forces
import imripy.constants as c

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})
solar_mass_to_pc = 4.8e-14
year_to_pc = 0.3064





# Setting initial and final conditions of the binary evolution for an eccentric orbit
e0 = 0.999

      
m1_arr = np.geomspace(1e5, 1e7, 10)  # in units of solar mass
m2_arr = np.geomspace(1, 100, 5)  # in units of solar mass
m1_list = m1_arr.tolist()
m2_list = m2_arr.tolist()



    
plt.figure(figsize = (12, 7.5))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)



for k, m2 in enumerate(m2_list):
    t_m1_list = np.zeros(len(m1_list))
    for i, m1 in enumerate(m1_list):
        m1 =  m1_list[i] * solar_mass_to_pc  
        m2 =  m2 * solar_mass_to_pc  
        D = 0
        accuracy = 1e-13
        alpha = 0.1
        f_edd = 0.1
        eps = 0.1
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        betaDisk = halo.BetaDisk(m1, alpha, f_edd, eps)
        sp_b_beta = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = betaDisk, D = D)
        opt_DF = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasDynamicalFriction()}, 
                                                 considerRelativeVelocities=True, progradeRotation=False, accuracy=accuracy, verbose=1)
        a0  =  500 * sp_0.r_isco()  #  a_i = (1e11 * r_isco of 1000 solar mass) in units of parsec
        R_fin = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        ev_beta = inspiral.Classic.Evolve(sp_b_beta, a0, e0, a_fin = R_fin)
        t_m1_list[i] = ev_beta.t[-1]/year_to_pc
        
    plt.loglog(m1_list, t_m1_list, '')
    slope, intercept = np.polyfit(np.log(m1_list), np.log(t_m1_list), 1)
    print('\v')
    print("intercept = ", '%0.4f'%intercept, "m =", '%0.4f'%slope)
   

    
plt.legend([m2_list[0], '%0.2f'%m2_list[1], m2_list[2], '%0.2f'%m2_list[3]
           ,m2_list[4]], title = '$m_{2} \: [M_{\odot}]$',
            title_fontsize = 16, loc = 'upper left', prop = {"size":14})
plt.xlabel('$m_{1} \, [M_{\odot}]$', fontsize = 26)
plt.ylabel('final merger time  [yr]', fontsize = 26)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.title(r'$ \beta - disk,\, e_{i} = 0.999$', fontsize = 32, pad = 9)
plt.savefig("t_mvsm1_β.pdf")
plt.grid()
plt.show()
# Out:
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2189s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1790s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2801s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2418s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.3587s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2316s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2106s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1934s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1906s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1923s
#
# intercept =  -712.6457 m = 61.9344
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2420s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2236s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2192s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2647s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1617s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2149s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1842s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1868s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1863s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1664s
#
# intercept =  -713.7970 m = 61.9344
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2304s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1798s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1543s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1424s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1487s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1394s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1355s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1300s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1334s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1335s
#
# intercept =  -714.9484 m = 61.9344
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1252s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1295s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1271s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1242s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1326s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1288s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1298s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1290s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1300s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1384s
#
# intercept =  -716.1000 m = 61.9344
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1459s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1331s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1287s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1412s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1581s
# Evolving from  499.99999999999994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1652s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1644s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1420s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1482s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1554s
#
# intercept =  -717.2524 m = 61.9345

# %%
# Setting initial and final conditions of the binary evolution for an eccentric orbit
e0 = 0.999

      
m1_arr = np.geomspace(1, 1e6, 5)  # in units of solar mass
m2_arr = np.geomspace(1e-5, 10, 20)  # in units of solar mass
m1_list = m1_arr.tolist()
m2_list = m2_arr.tolist()

plt.figure(figsize = (12, 7.5))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)



for k, m1 in enumerate(m1_list):
    t_m2_list = np.zeros(len(m2_list))
    for i, m2 in enumerate(m2_list):
        m1 =  m1_list[k] * solar_mass_to_pc  
        m2 =  m2 * solar_mass_to_pc  
        D = 0
        accuracy = 1e-13
        alpha = 0.1
        f_edd = 0.1
        eps = 0.1
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        betaDisk = halo.BetaDisk(m1, alpha, f_edd, eps)
        sp_b_beta = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = betaDisk, D = D)
        opt_DF = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasDynamicalFriction()}, 
                                                 considerRelativeVelocities=True, progradeRotation=False, accuracy=accuracy, verbose=1)
        a0  =  500 * sp_0.r_isco()  #  a_i = (1e11 * r_isco of 1000 solar mass) in units of parsec
        R_fin = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        ev_beta = inspiral.Classic.Evolve(sp_b_beta, a0, e0, a_fin = R_fin)
        t_m2_list[i] = ev_beta.t[-1]/year_to_pc
        
    plt.loglog(m2_list, t_m2_list, '')
    slope, intercept = np.polyfit(np.log(m2_list), np.log(t_m2_list), 1)
    print('\v')
    print("intercept = ", '%0.4f'%intercept, "m =", '%0.4f'%slope)

    
    
    
    
plt.legend([m1_list[0], '%0.2f'%m1_list[1], '$10^{3}$', r'$3.16 \times 10^{4}$',
            '$10^{6}$'], title = '$m_{1} \: [M_{\odot}]$',
            title_fontsize = 16, loc = 'upper right', prop = {"size":11})
plt.xlabel('$m_{2} \, [M_{\odot}]$', fontsize = 26)
plt.ylabel('final merger time / yr', fontsize = 26)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.title(r'$ \beta - disk,\, e_{i} = 0.999$', fontsize = 32, pad = 9)
plt.savefig("t_mvsm2_β.pdf", fontsize = 32, pad = 9)
plt.grid()
plt.show()
# Out:
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2765s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2767s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.4432s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.4034s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.3681s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2176s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1156s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1017s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1848s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0269s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0354s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0336s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0527s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8234s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7470s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7367s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8254s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0380s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0390s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0476s
#
# intercept =  -23.5077 m = -1.1153
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7338s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7403s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7346s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7205s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7366s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7208s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8895s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0291s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7962s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7643s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7393s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7335s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7485s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8407s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7259s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7255s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9159s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7670s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7407s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0040s
#
# intercept =  -15.7904 m = -1.0098
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0422s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0228s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8340s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7292s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7338s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8833s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0202s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0290s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0233s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0245s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9943s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0186s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7415s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8610s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7319s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9591s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7480s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8849s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0382s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7600s
#
# intercept =  -8.8122 m = -1.0003
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7620s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7726s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8467s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0272s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0494s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7584s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7976s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7592s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7596s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7368s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7606s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7555s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7644s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9980s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0391s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0378s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0014s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0598s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0372s
# Evolving from  500.0  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0369s
#
# intercept =  -1.9020 m = -1.0000
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9204s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7510s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7570s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8207s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7661s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7592s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9840s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7926s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7714s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7536s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9475s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8049s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7603s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7672s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9147s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0541s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0522s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0308s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8953s
# Evolving from  500.00000000000006  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, DynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0403s
#
# intercept =  5.0058 m = -1.0000
# /tmp/ipykernel_530128/2863142752.py:55: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "fontsize" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig("t_mvsm2_β.pdf", fontsize = 32, pad = 9)
# /tmp/ipykernel_530128/2863142752.py:55: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "pad" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig("t_mvsm2_β.pdf", fontsize = 32, pad = 9)

# %%
# γ = (61.9345 + 61.9344 + 61.9344)/3 
# γ = 61.9344

# So, t_m_beta  ∝ m_1^{γ}
# Out:
# 61.934433333333324

# %%
# δ = (-1.0000 - 1.0000 - 1.0003 - 1.0098 - 1.1153)/5
# δ = -1.0251


# So, t_m_beta  ∝ m_2^{δ}
# Out:
# -1.0250800000000002
