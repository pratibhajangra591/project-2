# %%
# Final merger time for the reference systems with masses m_1 = 1e5 M_solar
# and m_2 = 1 M_solar, as a function of the initial 
# angular momentum j0 for binaries having Power Law PDF (1-1e5) for PBHs having alpha-disk 
# with dynamical friction (Ostriker) as dissipative force.

# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import math
from matplotlib import rcParams
import matplotlib.pyplot as plt
from matplotlib.ticker import LogFormatterExponent
from matplotlib.colors import LogNorm
from matplotlib import ticker, cm
from accretion import *
import matplotlib as mpl
from matplotlib.lines import Line2D
from scipy.interpolate import interp1d
from scipy.integrate import quad
from scipy.special import gamma
from imripy import halo, constants as c, merger_system as ms, inspiral, waveform, detector, plot_utils
from imripy.inspiral import forces
import imripy.constants as c

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})


π = np.pi
Ω_cdm = 0.85
G = 4.4959e-15            #in units of M☉^-1 pc^3 yr^-2
c = 0.3068                #in units of pc yr^-1
ρ_eq = 3.1808e3           #in units of M☉ pc^-3 with ρ_eq=2.1548e-16 kg m^-3
pc = 3.0857e16            # in meters
yr = 3.154e7              # in units of seconds
t_eq = 1.5923e12/yr       # in units of seconds
t_0 = 13.78e9             #in units of yrs corresponding to t_0=13.78Gyr
ρ_m = 4e19                #ρ_m = 4e19 M☉ Gpc^-3
M_solar = 1.989e30        # in units of kg
σ_eq = 0.005

solar_mass_to_pc = 4.8e-14
year_to_pc = 0.3064





# The initial value of a_i or a_i_ref is calculated for a reference
# binary with PBHs of masses m_1 = 1e5 solar mass and m_2  = 1 solar mass 
# (chosen by choice).
bin_centres = np.geomspace(1, 1e5, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])
ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 
deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()
m1_arr = np.geomspace(1, 1e5, 5)
m2_arr = np.geomspace(1, 1e5, 5)
   


#Setting up the binary system with initial and final conditions of the binary evolution for an eccentric orbit
m1 =  m1_arr[-1] * solar_mass_to_pc  
m2 =  m2_arr[0] * solar_mass_to_pc  
a0  =  (6 * G * m1_arr[-1])/(c**2)      #a_i = (r_isco of m1 solar mass) in units of parsec
print("a0 = ", '%0.4f'%a0, "pc")
a0_arr = np.linspace(100*a0 , 500*a0 , 10)
e0_arr = 1- np.geomspace(0.1, 1e-5, 6) 

def j0(e0):
    return np.sqrt(1 - (e0**2))
j0_arr = np.zeros(len(e0_arr))
for i, e0 in enumerate(e0_arr):
    j0_arr[i] = j0(e0)


    
    


fig,ax = plt.subplots(1, figsize = (14, 7.8))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 3, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 7, direction = 'in')


colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']
for k, (e0, color) in enumerate(zip(e0_arr, colors)):
    tm_arr_0 = np.zeros(len(a0_arr))
    tm_arr_DF = np.zeros(len(a0_arr))
    tm_arr_gwDF = np.zeros(len(a0_arr))
    for i, a0 in enumerate (a0_arr):
        D = 0
        accuracy = 1e-10
        e0 = e0_arr[k]
        a0 = a0_arr[i]
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        opt_0 = inspiral.Classic.EvolutionOptions(accuracy=accuracy, verbose=1, 
                gwEmissionLoss = True, dynamicalFrictionLoss = False)
        R_fin_0 = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        alpha = 0.1
        f_edd = 0.1
        eps  = 0.1
        betaDisk = halo.AlphaDisk(m1, alpha, f_edd, eps)
        sp_beta  = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = betaDisk, D=D)
        R_fin = sp_beta.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        opt_DF = inspiral.Classic.EvolutionOptions(gwEmissionLoss = False, dissipativeForces={forces.GasDynamicalFriction()}, 
                considerRelativeVelocities= True, progradeRotation=False, accuracy=accuracy, verbose=1)

        opt_gwDF = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasDynamicalFriction()}, 
                  gwEmissionLoss = True, dynamicalFrictionLoss = True, considerRelativeVelocities= True, 
                  progradeRotation = False, accuracy=accuracy, verbose=1)

        ev_0 = inspiral.Classic.Evolve(sp_0, a0, e0, a_fin=R_fin_0, opt=opt_0)   
        ev_beta_DF = inspiral.Classic.Evolve(sp_beta, a0, e0, a_fin=R_fin, opt=opt_DF)   
        ev_beta_gwDF = inspiral.Classic.Evolve(sp_beta, a0, e0, a_fin=R_fin, opt=opt_gwDF)   
        
        tm_arr_0[i]    =  ev_0.t[-1]/year_to_pc
        tm_arr_DF[i]   =  ev_beta_DF.t[-1]/year_to_pc
        tm_arr_gwDF[i] =  ev_beta_gwDF.t[-1]/year_to_pc
        
    ax.loglog(a0_arr, tm_arr_DF, color = color, linestyle = '--')
    ax.loglog(a0_arr, tm_arr_0, color = color,   linestyle = ':')
    ax.loglog(a0_arr, tm_arr_gwDF, color = color, linestyle = '-')

    
    slope_0, intercept_0 = np.polyfit(np.log(a0_arr), np.log(tm_arr_0), 1)
    slope_DF, intercept_DF = np.polyfit(np.log(a0_arr), np.log(tm_arr_DF), 1)
    slope_gwDF, intercept_gwDF = np.polyfit(np.log(a0_arr), np.log(tm_arr_gwDF), 1)
    print('\v')
    print("No Accretion (GW),", "intercept = ", '%0.4f'%intercept_0, "," , "m =", '%0.4f'%slope_0)
    print('α - disk(DF)', "intercept = ", '%0.4f'%intercept_DF,  "," , "m =", '%0.4f'%slope_DF)
    print('α - disk (gw + DF) ', "intercept = ", '%0.4f'%intercept_gwDF,  "," , "m =", '%0.4f'%slope_gwDF)



ax.tick_params(axis='x', pad = 8.9)
ax.tick_params(axis='y', pad = 8.9)
# In total 3x6 lines have been plotted
lines = ax.get_lines()
legend1 = plt.legend([lines[i] for i in [0,1,2]], ["DF", "GW", "DF + GW"], title = 'Dissiptaive Force', title_fontsize = 23,
                     loc = (1.02, 0.7), prop = {"size":16})
legend2 = plt.legend([lines[i] for i in [2,5,8,11, 14, 17]], ['$0.44$', '$0.17$', 
          r'$0.07$', r'$0.02$', r'$0.01$', r'$0.004$'], title = '$j_{i}$',
           title_fontsize = 27, loc = (1.02, 0.1), prop = {"size":22})

ax.add_artist(legend1)
ax.add_artist(legend2)

plt.xlabel('$a_{i} \, \mathrm{[pc]}$', fontsize = 26)
plt.ylabel('final merger time \,[yr]', fontsize = 26)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.title(r'$\beta-\mathrm{disk}, \: m_{1} = 10^{5} \, \mathrm{M_{\odot}}$,\: $m_{2}= 1 \,  \mathrm{M_{\odot}}$ ', fontsize = 30, pad = 9)
plt.savefig('tm_vs_ai1_β.pdf', bbox_inches='tight')
plt.show()
# Out:
# a0 =  0.0000 pc
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1596s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 10.3519s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3432s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1728s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 13.1489s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.0376s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1832s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 15.5338s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# A termination event occurred.
#  -> Evolution took 15.4558s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2060s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 69.9281s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.7430s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1957s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 72.5768s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.0690s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1962s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 85.0458s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.4227s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2046s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 65.3841s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.8527s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2052s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 86.3027s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.4845s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2072s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 88.5590s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.5383s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2102s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 89.5695s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 19.1936s
#
# No Accretion (GW), intercept =  60.5421 , m = 4.0000
# α - disk(DF) intercept =  60.7244 , m = 4.0000
# α - disk (gw + DF)  intercept =  -29.0632 , m = -2.6686
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1487s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.1911s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8817s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1527s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 6.1999s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.8200s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1735s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 43.3943s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.4146s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1800s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 78.1027s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.4218s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1804s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 84.3581s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# A termination event occurred.
#  -> Evolution took 16.8995s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1849s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 59.9397s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.7121s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1897s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 71.6608s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.0069s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1971s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 87.0844s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:207: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# A termination event occurred.
#  -> Evolution took 17.5851s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2007s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 102.8787s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 56.0328s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2054s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 122.1440s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 72.5242s
#
# No Accretion (GW), intercept =  54.4864 , m = 4.0005
# α - disk(DF) intercept =  54.6625 , m = 4.0000
# α - disk (gw + DF)  intercept =  -23.8145 , m = -2.1270
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1252s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2344s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8581s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1337s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2332s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.8322s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1420s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.4466s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.6239s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1494s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.2175s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.9709s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1498s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 53.2875s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.9017s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1658s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 74.4897s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.9844s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1533s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 64.5240s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.5926s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1587s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 102.7850s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 56.7489s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1720s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 105.4986s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 56.2165s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1711s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 72.3997s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 57.6728s
#
# No Accretion (GW), intercept =  48.3810 , m = 4.0173
# α - disk(DF) intercept =  48.3681 , m = 4.0000
# α - disk (gw + DF)  intercept =  11.4176 , m = 1.0312
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1242s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1741s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.4395s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1270s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2335s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.1816s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1334s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2677s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.6528s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1358s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.7240s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.8309s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1511s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3773s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 23.7855s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1509s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3537s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 21.6725s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1554s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3974s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 23.6648s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1492s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.2874s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 26.1857s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1608s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 5.2662s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 29.0577s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1630s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 7.8697s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 30.3875s
#
# No Accretion (GW), intercept =  42.1509 , m = 4.0325
# α - disk(DF) intercept =  41.9823 , m = 4.0000
# α - disk (gw + DF)  intercept =  40.6686 , m = 3.9114
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1222s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1700s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.5590s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1287s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.7045s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.8840s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1350s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.2940s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 19.4588s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1393s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3893s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 24.3065s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1395s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.9660s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 27.7868s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1485s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0158s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 29.8973s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1467s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.9791s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 32.6829s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1460s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.9932s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 34.8671s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1547s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0301s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 37.2006s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1539s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0164s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 37.9488s
#
# No Accretion (GW), intercept =  35.7464 , m = 4.0356
# α - disk(DF) intercept =  35.5597 , m = 4.0000
# α - disk (gw + DF)  intercept =  35.7429 , m = 4.0353
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1220s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0952s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.3074s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1262s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0937s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8077s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1300s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1610s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.2710s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1297s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.9778s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.1659s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1353s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7164s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 24.5126s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1378s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7534s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 33.9480s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1620s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.8638s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 40.4994s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1465s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.8030s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 42.7369s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1387s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.6971s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 44.9373s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1421s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7048s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# A termination event occurred.
#  -> Evolution took 47.2982s
#
# No Accretion (GW), intercept =  29.3062 , m = 4.0361
# α - disk(DF) intercept =  29.1223 , m = 4.0000
# α - disk (gw + DF)  intercept =  29.3061 , m = 4.0361

# %%
# The initial value of a_i or a_i_ref is calculated for a reference
# binary with PBHs of masses m_1 = 1e6 solar mass and m_2 = 10 solar mass 
# (chosen by choice).
bin_centres = np.geomspace(10, 1e6, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])
ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 
deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()
m_1 = np.geomspace(10, 1e6, 5)
m_2 = np.geomspace(10, 1e6, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   


    
#Setting up the binary system with initial and final conditions of the binary evolution for an eccentric orbit
m1 =  m1_arr[-1] * solar_mass_to_pc  
m2 =  m2_arr[0] * solar_mass_to_pc  
a0  =  (6 * G * m1_arr[-1])/(c**2)      #a_i = (r_isco of m1 solar mass) in units of parsec
print("a0 = ", '%0.4e'%a0, "pc")
a0_arr = np.linspace(100*a0 , 500*a0 , 10)
e0_arr = 1- np.geomspace(0.1, 1e-5, 6) 

def j0(e0):
    return np.sqrt(1 - (e0**2))
j0_arr = np.zeros(len(e0_arr))
for i, e0 in enumerate(e0_arr):
    j0_arr[i] = j0(e0)


    
    


fig,ax = plt.subplots(1, figsize = (14, 7.8))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 3, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 7, direction = 'in')


colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']
for k, (e0, color) in enumerate(zip(e0_arr, colors)):
    tm_arr_0 = np.zeros(len(a0_arr))
    tm_arr_DF = np.zeros(len(a0_arr))
    tm_arr_gwDF = np.zeros(len(a0_arr))
    for i, a0 in enumerate (a0_arr):
        D = 0
        accuracy = 1e-10
        e0 = e0_arr[k]
        a0 = a0_arr[i]
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        opt_0 = inspiral.Classic.EvolutionOptions(accuracy=accuracy, verbose=1, 
                gwEmissionLoss = True, dynamicalFrictionLoss = False)
        R_fin_0 = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        alpha = 0.1
        f_edd = 0.1
        eps  = 0.1
        betaDisk = halo.AlphaDisk(m1, alpha, f_edd, eps)
        sp_beta  = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = betaDisk, D=D)
        R_fin = sp_beta.r_isco()      # The final condition for the evolution, Choosen equal to r_icso

        opt_DF = inspiral.Classic.EvolutionOptions(gwEmissionLoss = False, dissipativeForces={forces.GasDynamicalFriction()}, 
                considerRelativeVelocities= True, progradeRotation=False, accuracy=accuracy, verbose=1)

        opt_gwDF = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasDynamicalFriction()}, 
                  gwEmissionLoss = True, dynamicalFrictionLoss = True, considerRelativeVelocities= True, 
                  progradeRotation = False, accuracy=accuracy, verbose=1)

        ev_0 = inspiral.Classic.Evolve(sp_0, a0, e0, a_fin=R_fin_0, opt=opt_0)   
        ev_beta_DF = inspiral.Classic.Evolve(sp_beta, a0, e0, a_fin=R_fin, opt=opt_DF)   
        ev_beta_gwDF = inspiral.Classic.Evolve(sp_beta, a0, e0, a_fin=R_fin, opt=opt_gwDF)   
        
        tm_arr_0[i]    =  ev_0.t[-1]/year_to_pc
        tm_arr_DF[i]   =  ev_beta_DF.t[-1]/year_to_pc
        tm_arr_gwDF[i] =  ev_beta_gwDF.t[-1]/year_to_pc
        
    ax.loglog(a0_arr, tm_arr_DF, color = color, linestyle = '--')
    ax.loglog(a0_arr, tm_arr_0, color = color,   linestyle = ':')
    ax.loglog(a0_arr, tm_arr_gwDF, color = color, linestyle = '-')

    
    slope_0, intercept_0 = np.polyfit(np.log(a0_arr), np.log(tm_arr_0), 1)
    slope_DF, intercept_DF = np.polyfit(np.log(a0_arr), np.log(tm_arr_DF), 1)
    slope_gwDF, intercept_gwDF = np.polyfit(np.log(a0_arr), np.log(tm_arr_gwDF), 1)
    print('\v')
    print("No Accretion (GW),", "intercept = ", '%0.4f'%intercept_0, "," , "m =", '%0.4f'%slope_0)
    print('α - disk(DF)', "intercept = ", '%0.4f'%intercept_DF,  "," , "m =", '%0.4f'%slope_DF)
    print('α - disk (gw + DF) ', "intercept = ", '%0.4f'%intercept_gwDF,  "," , "m =", '%0.4f'%slope_gwDF)



ax.tick_params(axis='x', pad = 8.9)
ax.tick_params(axis='y', pad = 8.9)
# In total 3x6 lines have been plotted
lines = ax.get_lines()
legend1 = plt.legend([lines[i] for i in [0,1,2]], ["DF", "GW", "DF + GW"], title = 'Dissiptaive Force', title_fontsize = 23,
                     loc = (1.02, 0.7), prop = {"size":16})
legend2 = plt.legend([lines[i] for i in [2,5,8,11, 14, 17]], ['$0.44$', '$0.17$', 
          r'$0.07$', r'$0.02$', r'$0.01$', r'$0.004$'], title = '$j_{i}$',
           title_fontsize = 27, loc = (1.02, 0.1), prop = {"size":22})

ax.add_artist(legend1)
ax.add_artist(legend2)

plt.xlabel('$a_{i} \, \mathrm{[pc]}$', fontsize = 26)
plt.ylabel('final merger time \,[yr]', fontsize = 26)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)
plt.title(r'$\beta-\mathrm{disk}, \: m_{1} = 10^{6} \, \mathrm{M_{\odot}}$,\: $m_{2}= 10 \,  \mathrm{M_{\odot}}$ ', fontsize = 30, pad = 9)
plt.savefig('tm_vs_ai2_β.pdf', bbox_inches='tight')
plt.show()
# Out:
# a0 =  0.0000 pc
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1785s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 10.3401s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3369s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1724s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 13.1074s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.9122s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1825s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 14.9742s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# A termination event occurred.
#  -> Evolution took 15.3236s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1896s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 70.0666s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.7410s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1940s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 72.9047s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.2369s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1997s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 84.0030s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.2044s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2002s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 64.7157s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.5669s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2023s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 85.4819s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.4269s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2072s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 88.9882s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.6535s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2198s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 87.2342s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 19.3589s
#
# No Accretion (GW), intercept =  60.5421 , m = 4.0000
# α - disk(DF) intercept =  60.7244 , m = 4.0000
# α - disk (gw + DF)  intercept =  -29.0632 , m = -2.6686
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1514s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.1457s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.2928s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1631s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 6.4786s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.8370s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1598s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 42.1967s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.7081s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2217s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 79.4285s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.4778s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1997s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 85.5988s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# A termination event occurred.
#  -> Evolution took 17.0546s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1901s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 63.8996s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.9804s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1933s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 73.9932s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.4321s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2066s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 91.9863s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:207: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# A termination event occurred.
#  -> Evolution took 18.2072s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1967s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 104.2072s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 56.8976s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1976s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 122.6100s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9841510680753889  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 74.6472s
#
# No Accretion (GW), intercept =  54.4864 , m = 4.0005
# α - disk(DF) intercept =  54.6625 , m = 4.0000
# α - disk (gw + DF)  intercept =  -23.8145 , m = -2.1270
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1273s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2410s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3038s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1407s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2423s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.4678s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1526s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.4649s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.0569s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1437s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.2310s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.4929s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1512s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 55.3994s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.2814s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1531s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 75.5581s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.4972s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1792s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 66.6970s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.0583s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1686s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 100.1376s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 54.5475s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1641s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 101.0752s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 56.2541s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1919s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 74.8655s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9974881135684904  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 59.7087s
#
# No Accretion (GW), intercept =  48.3810 , m = 4.0173
# α - disk(DF) intercept =  48.3681 , m = 4.0000
# α - disk (gw + DF)  intercept =  11.4176 , m = 1.0312
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1237s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1687s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.1367s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1325s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2402s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.6240s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1427s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2733s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.0814s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1476s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.7961s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 17.8188s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1431s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3456s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 23.5475s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1524s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3626s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 22.0738s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1603s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3799s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 24.6052s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1622s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.5162s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 27.0511s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1593s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 5.3461s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 29.7907s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1599s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 8.2179s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9996018928294464  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 31.3140s
#
# No Accretion (GW), intercept =  42.1509 , m = 4.0325
# α - disk(DF) intercept =  41.9823 , m = 4.0000
# α - disk (gw + DF)  intercept =  40.6686 , m = 3.9114
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1196s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1641s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8098s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1324s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.7230s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.4959s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1582s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3282s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.8659s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1335s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3613s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 24.0107s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1426s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0429s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 28.5569s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1462s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0443s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 31.1698s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1453s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0052s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 32.4289s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1464s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.9767s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 35.6497s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1513s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.1123s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 37.5869s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1440s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0050s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.9999369042655519  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 39.0666s
#
# No Accretion (GW), intercept =  35.7464 , m = 4.0356
# α - disk(DF) intercept =  35.5597 , m = 4.0000
# α - disk (gw + DF)  intercept =  35.7429 , m = 4.0353
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1272s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0997s
# Evolving from  99.50953457116032  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8811s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1356s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1002s
# Evolving from  143.7359943805649  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.6805s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1320s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1664s
# Evolving from  187.9624541899695  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3646s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1344s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:419: RuntimeWarning: invalid value encountered in sqrt
#   Omega = np.sqrt(self.M/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.9941s
# Evolving from  232.18891399937408  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.2964s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1342s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.8547s
# Evolving from  276.41537380877867  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 25.2856s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1457s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7957s
# Evolving from  320.6418336181832  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 34.3190s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1430s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.8028s
# Evolving from  364.86829342758784  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 38.3049s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1360s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.6511s
# Evolving from  409.0947532369924  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 42.5448s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1397s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7556s
# Evolving from  453.321213046397  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 45.6125s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1488s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.6687s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# A termination event occurred.
#  -> Evolution took 46.9405s
#
# No Accretion (GW), intercept =  29.3062 , m = 4.0361
# α - disk(DF) intercept =  29.1223 , m = 4.0000
# α - disk (gw + DF)  intercept =  29.3061 , m = 4.0361

# %%
# The initial value of a_i or a_i_ref is calculated for a reference
# binary with PBHs of masses m_1 = 1e4 solar mass and m_2 = 0.1 solar mass 
# (chosen by choice).
bin_centres = np.geomspace(0.1, 1e4, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])
ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 
deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()
m_1 = np.geomspace(0.1, 1e4, 5)
m_2 = np.geomspace(0.1, 1e4, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   


    

e0_arr = 1- np.geomspace(1e-5, 0.1, 6) 

def j0(e0):
    return np.sqrt(1 - (e0**2))
j0_arr = np.zeros(len(e0_arr))
for i, e0 in enumerate(e0_arr):
    j0_arr[i] = j0(e0)

j0_arr
# Out:
# array([0.00447212, 0.01123332, 0.02821446, 0.07083405, 0.1773321 ,
#        0.43588989])

# %%
### So, the dependence of final merger time of PBH binaries with static 
# accretion disk of beta type is given as:


#           t_m_beta ∝ a_i^{m}   with  m = 4.0000.
# Out:
# 3.3302128296074944e-07
