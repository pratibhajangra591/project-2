# %%
# Final merger time for the reference systems with masses m_1 = 1e5 M_solar
# and m_2 = 1 M_solar, as a function of the initial 
# angular momentum j0 for binaries having Power Law PDF (1-1e5) for PBHs having alpha-disk 
# with dynamical friction (Ostriker) as dissipative force.

# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import math
from matplotlib import rcParams
import matplotlib.pyplot as plt
from matplotlib.ticker import LogFormatterExponent
from matplotlib.colors import LogNorm
from matplotlib import ticker, cm
from accretion import *
import matplotlib as mpl
from matplotlib.lines import Line2D
from scipy.interpolate import interp1d
from scipy.integrate import quad
from scipy.special import gamma
from imripy import halo, constants as c, merger_system as ms, inspiral, waveform, detector, plot_utils
from imripy.inspiral import forces
import imripy.constants as c

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})
solar_mass_to_pc = 4.8e-14
year_to_pc = 0.3064



π = np.pi
Ω_cdm = 0.85
G = 4.4959e-15            #in units of M☉^-1 pc^3 yr^-2
c = 0.3068                #in units of pc yr^-1
ρ_eq = 3.1808e3           #in units of M☉ pc^-3 with ρ_eq=2.1548e-16 kg m^-3
pc = 3.0857e16            # in meters
yr = 3.154e7              # in units of seconds
t_eq = 1.5923e12/yr      # in units of seconds
t_m = 13.78e9             #in units of yrs corresponding to t_0=13.78Gyr
t_0 = 13.78e9             #in units of yrs corresponding to t_0=13.78Gyr

σ_eq = 0.005
ρ_m = 4e19                #ρ_m = 4e19 M☉ Gpc^-3



#1.) SystemProp(m1, m2, halo, D=D, inclination_angle = 0., pericenter_angle=0.,
# baryonicHalo=None, includeHaloInTotalMass=False):
    
#2.) EvolutionOptions(accuracy=1e-10, verbose=1, elliptic=True, m2_change=False,
# dissipativeForces=None, gwEmissionLoss = True, dynamicalFrictionLoss = True,
# considerRelativeVelocities=False, progradeRotation = True, **kwargs)

#3.) Evolve(sp, a_0, e_0=0., a_fin=0., t_0=0., t_fin=None, opt=EvolutionOptions())
# t_fin = None means t_fin = Time of coalescence on the system.


 
#4.) opt_0 = EvolutionOptions(accuracy=1e-10, verbose=1, elliptic=True, m2_change=False,
# dissipativeForces=None, gwEmissionLoss = True, dynamicalFrictionLoss = True,
# considerRelativeVelocities=False, progradeRotation = True)or 
# or
#4.) opt_0 = inspiral.Classic.EvolutionOptions(dynamicalFrictionLoss=False, verbose=1, accuracy=1e-10)

# %%
# Final merger time vs m1 for IMRI with α-accretion disk having dynamical 
# friction as the dissipative force.



# Setting initial and final conditions of the binary evolution for an eccentric orbit
e0 = 0.999
m1_arr = np.geomspace(1e5, 1e7, 50)  # in units of solar mass
m2_arr = np.geomspace(1, 100, 4)  # in units of solar mass


fig,ax = plt.subplots(1, figsize = (14, 7.8))
plt.rc('lines', linewidth = 1.6)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 3, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 7, direction = 'in')

colors = ['C0', 'C1', 'C2', 'C3']
plot_lines = []

for k, (m2, color) in enumerate(zip(m2_arr, colors)):
    tm_arr_0 = np.zeros(len(m1_arr))
    tm_arr_DF = np.zeros(len(m1_arr))
    tm_arr_gwDF = np.zeros(len(m1_arr))
    for i, m1 in enumerate(m1_arr):
        m1 =  m1_arr[i] * solar_mass_to_pc  
        m2 =  m2_arr[k] * solar_mass_to_pc  
        D = 0
        a0  =  500 * ((6 * G * 1e5)/(c**2)) #  a_i = (500 * r_isco of 1e5 solar mass) in units of parsec
        accuracy = 1e-10
        
        
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        opt_0 = inspiral.Classic.EvolutionOptions(accuracy=accuracy, verbose=1, 
                    gwEmissionLoss = True, dynamicalFrictionLoss = False)
        R_fin_0 = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso
        ev_0 = inspiral.Classic.Evolve(sp_0, a0, e0, a_fin=R_fin_0, opt=opt_0)   
        tm_arr_0[i] = ev_0.t[-1]/year_to_pc
        
        
        alpha = 0.1
        f_edd = 0.1
        eps   = 0.1
        alphaDisk = halo.AlphaDisk(m1, alpha, f_edd, eps)
        sp_alpha  = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = alphaDisk, D=D)
        R_fin = sp_alpha.r_isco()      # The final condition for the evolution, Choosen equal to r_icso
       
        opt_DF    = inspiral.Classic.EvolutionOptions(gwEmissionLoss = False, dissipativeForces={forces.GasDynamicalFriction()}, 
                    considerRelativeVelocities= True, progradeRotation=False, accuracy=accuracy, verbose=1)
        
        opt_gwDF    = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasDynamicalFriction()}, 
                      gwEmissionLoss = True, dynamicalFrictionLoss = True, considerRelativeVelocities= True, 
                      progradeRotation = False, accuracy=accuracy, verbose=1)
       
        ev_alpha_DF = inspiral.Classic.Evolve(sp_alpha, a0, e0, a_fin=R_fin, opt=opt_DF)   
        tm_arr_DF[i] = ev_alpha_DF.t[-1]/year_to_pc
        ev_alpha_gwDF = inspiral.Classic.Evolve(sp_alpha, a0, e0, a_fin=R_fin, opt=opt_gwDF)   
        tm_arr_gwDF[i] = ev_alpha_gwDF.t[-1]/year_to_pc
        
    

    ax.loglog(m1_arr, tm_arr_DF, color = color, linestyle = '--')
    ax.loglog(m1_arr, tm_arr_0, color = color, linestyle = ':')
    ax.loglog(m1_arr, tm_arr_gwDF, color = color, linestyle = '-')

    
    slope_0, intercept_0 = np.polyfit(np.log(m1_arr), np.log(tm_arr_0), 1)
    slope_DF, intercept_DF = np.polyfit(np.log(m1_arr), np.log(tm_arr_DF), 1)
    slope_gwDF, intercept_gwDF = np.polyfit(np.log(m1_arr), np.log(tm_arr_gwDF), 1)
    print('\v')
    print("No Accretion (GW),", "intercept = ", '%0.4f'%intercept_0, "," , "m =", '%0.4f'%slope_0)
    print('α - disk(DF)', "intercept = ", '%0.4f'%intercept_DF,  "," , "m =", '%0.4f'%slope_DF)
    print('α - disk (gw + DF) ', "intercept = ", '%0.4f'%intercept_gwDF,  "," , "m =", '%0.4f'%slope_gwDF)

    
    
    
ax.tick_params(axis='x', pad = 8.9)
ax.tick_params(axis='y', pad = 8.9)
# In total 3x4 lines have been plotted
lines = ax.get_lines()
legend1 = plt.legend([lines[i] for i in [0,1,2]], ["DF", "GW", "DF + GW"], title = 'Dissiptaive Force',
        title_fontsize = 23, loc = 'upper right', prop = {"size":13})
legend2 = plt.legend([lines[i] for i in [2,5,8,11]], ['$1$', r'$4.64$', 
           r'$21.45$', '$100$'], title = '$m_{2} \: \mathrm{[M_{\odot}]}$',
           title_fontsize = 27, loc = (1.02, 0.25), prop = {"size":28})

ax.add_artist(legend1)
ax.add_artist(legend2)

plt.xlabel('$m_{1} \, \mathrm{[M_{\odot}]}$', fontsize = 35, labelpad = 15)
plt.ylabel('Final merger time  [yr]', fontsize = 35, labelpad = 15)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.title(r'$ \alpha-\mathrm{disk},\, a_{i} = 500\,r_\mathrm{isco}(m = 10^{5}\, \mathrm{M_{\odot}}),\, e_{i} = 0.999$', fontsize = 32, pad = 9)
plt.savefig("tm_vs_m1_α_DF.pdf", bbox_inches = 'tight')
plt.show()
# Out:
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1517s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 44.3147s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 35.1158s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1828s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 73.6545s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 35.8222s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2045s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 53.4526s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 30.9854s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1954s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 47.9832s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 21.5826s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1918s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 24.0373s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 18.7231s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1743s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 15.9360s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.5972s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1731s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.2231s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.4637s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1783s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.4393s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.2107s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1712s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.3677s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.1175s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1662s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2721s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.2120s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1774s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2949s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.4852s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1737s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2814s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.2957s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1739s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2994s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 15.2238s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1556s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2762s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.7762s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1534s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2748s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.4113s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1510s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2733s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.3286s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1487s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2751s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.0148s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1435s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2697s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.4102s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1406s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2721s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.1773s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1386s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2717s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 13.0106s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1358s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2705s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.7350s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1322s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2697s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.4560s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1309s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2718s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3856s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1311s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2873s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 12.3928s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1271s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2684s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.8047s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1233s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1926s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.6375s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1231s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1897s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.4370s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1206s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1902s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.2148s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1264s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1877s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.2177s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1197s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1953s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.0566s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1265s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2004s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.8272s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1150s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1937s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.6856s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1121s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1947s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.4860s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1113s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1955s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.3421s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1068s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1943s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.0039s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1071s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1958s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.8023s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1024s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2001s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.6989s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1003s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1962s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.4591s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1009s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2004s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.2499s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0975s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1999s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.0517s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0920s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2004s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.6518s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0898s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1976s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.4369s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0952s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1994s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.0915s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0832s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1990s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.7944s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0803s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1973s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.5093s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0791s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2019s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.4196s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0758s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1950s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.9576s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0712s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1136s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.7494s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0688s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1140s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.3130s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0640s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1127s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.0191s
#
# No Accretion (GW), intercept =  24.6316 , m = -2.0991
# α - disk(DF) intercept =  23.5967 , m = -2.0001
# α - disk (gw + DF)  intercept =  22.4538 , m = -1.9507
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1972s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:314: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log((1. + np.abs(v_rel)/c_s)/(1. - np.abs(v_rel)/c_s)) - np.abs(v_rel)/c_s) # subsonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:313: RuntimeWarning: invalid value encountered in log
#   1./2. * np.log(1. - (c_s/np.abs(v_rel))**2) + ln_Lambda, # supersonic regime
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 50.1229s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# A termination event occurred.
#  -> Evolution took 65.8082s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1843s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 48.4478s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 58.9698s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2030s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 50.0426s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 50.3377s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1842s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 27.9800s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 50.2526s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1870s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 15.2568s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 49.5407s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1802s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 14.1950s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 43.6789s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1769s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 12.8114s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 36.3896s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1814s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.1301s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 31.1662s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1635s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.8562s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 23.6875s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1654s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.2991s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 22.6478s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1583s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.3088s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 20.2360s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1552s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.6520s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.8155s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1771s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.6714s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 16.1259s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1575s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.3109s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 14.6385s
# ...
# A termination event occurred.
#  -> Evolution took 12.1360s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1241s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.5080s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 11.9255s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1222s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2477s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.9209s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1159s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2192s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.6341s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1124s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1914s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.6774s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1082s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1910s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.2468s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1082s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1926s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.0990s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1081s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1965s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 10.0609s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1070s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1939s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.7485s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1037s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1965s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.7340s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1003s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2147s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 9.4117s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0935s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1924s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.8382s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0912s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1924s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.5837s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0881s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1911s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.3905s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0869s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1909s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 8.1511s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0824s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1902s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.8105s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0821s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1923s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.5175s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0769s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1901s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 7.2593s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0738s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1883s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.9778s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0701s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1070s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.6447s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0695s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1083s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.3818s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0639s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1071s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 6.0738s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0627s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GasDynamicalFriction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1085s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.999  with  Options: dissipative Forces emplyed {GWLoss, GasDynamicalFriction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 5.7572s
#
# No Accretion (GW), intercept =  20.0239 , m = -2.0989
# α - disk(DF) intercept =  18.9890 , m = -2.0000
# α - disk (gw + DF)  intercept =  18.2682 , m = -1.9793

# %%
# Final merger time vs m1 for IMRI with α-accretion disk having Type-I
# migration as the dissipative force.
# Type- I migration is not valid for e > 0.001.


# Setting initial and final conditions of the binary evolution for an eccentric orbit
e0 = 1e-4   # Type- I migration is not valid for e > 0.001.
m1_arr = np.geomspace(1e5, 1e7, 50)  # in units of solar mass
m2_arr = np.geomspace(1, 100, 4)  # in units of solar mass


fig,ax = plt.subplots(1, figsize = (14, 7.8))
plt.rc('lines', linewidth = 1.7)
plt.rcParams['font.family'] = 'serif'
plt.tick_params(axis = 'both', right=True, top=True, which = 'minor', width= 1.2, length = 3, direction = 'in')
plt.tick_params(axis = 'both', right=True, top=True, which = 'major', width= 1.2, length = 7, direction = 'in')

colors = ['C0', 'C1', 'C2', 'C3']
plot_lines = []
for k, (m2, color) in enumerate(zip(m2_arr, colors)):
    tm_arr_0 = np.zeros(len(m1_arr))
    tm_arr_TypeI = np.zeros(len(m1_arr))
    tm_arr_gwTypeI = np.zeros(len(m1_arr))
    for i, m1 in enumerate(m1_arr):
        m1 =  m1_arr[i] * solar_mass_to_pc  
        m2 =  m2_arr[k] * solar_mass_to_pc  
        D = 0
        a0  =  500 * ((6 * G * 1e5)/(c**2))     #  a_i = (500 * r_isco of 1e5 solar mass) in units of parsec
        accuracy = 1e-10
        
        
        sp_0 = ms.SystemProp(m1, m2, halo.ConstHalo(0.), D)
        opt_0 = inspiral.Classic.EvolutionOptions(accuracy=accuracy, verbose=1, 
                    gwEmissionLoss = True, dynamicalFrictionLoss = False)
        R_fin_0 = sp_0.r_isco()      # The final condition for the evolution, Choosen equal to r_icso
        ev_0 = inspiral.Classic.Evolve(sp_0, a0, e0, a_fin=R_fin_0, opt=opt_0)   
        tm_arr_0[i] = ev_0.t[-1]/year_to_pc
        
        
        alpha = 0.1
        f_edd = 0.1
        eps   = 0.1
        alphaDisk = halo.AlphaDisk(m1, alpha, f_edd, eps)
        sp_alpha  = ms.SystemProp(m1, m2, halo.ConstHalo(0.), baryonicHalo = alphaDisk, D=D)
        R_fin = sp_alpha.r_isco()      # The final condition for the evolution, Choosen equal to r_icso
       
        opt_TypeI    = inspiral.Classic.EvolutionOptions(gwEmissionLoss = False, dissipativeForces={forces.GasInteraction()}, 
                    considerRelativeVelocities = False, progradeRotation= True, accuracy=accuracy, verbose=1)
        
        opt_gwTypeI    = inspiral.Classic.EvolutionOptions(dissipativeForces={forces.GWLoss(), forces.GasInteraction()}, 
                    gwEmissionLoss = True, dynamicalFrictionLoss = True,considerRelativeVelocities=False,
                            progradeRotation = True, accuracy=accuracy, verbose=1)
       
        ev_alpha_TypeI    = inspiral.Classic.Evolve(sp_alpha, a0, e0, a_fin=R_fin, opt=opt_TypeI)   
        tm_arr_TypeI[i]   = ev_alpha_TypeI.t[-1]/year_to_pc
        ev_alpha_gwTypeI  = inspiral.Classic.Evolve(sp_alpha, a0, e0, a_fin=R_fin, opt=opt_gwTypeI)   
        tm_arr_gwTypeI[i] = ev_alpha_gwTypeI.t[-1]/year_to_pc
        
    
    
    ax.loglog(m1_arr, tm_arr_TypeI, color = color,  linestyle = '--')
    ax.loglog(m1_arr, tm_arr_0,  color = color,       linestyle = ':')
    ax.loglog(m1_arr, tm_arr_gwTypeI, color = color, linestyle = '-')
    
    slope_0, intercept_0  = np.polyfit(np.log(m1_arr), np.log(tm_arr_0), 1)
    slope_TypeI, intercept_TypeI = np.polyfit(np.log(m1_arr), np.log(tm_arr_TypeI), 1)
    slope_gwTypeI, intercept_gwTypeI = np.polyfit(np.log(m1_arr), np.log(tm_arr_gwTypeI), 1)
    print('\v')
    print("No Accretion (GW),", "intercept = ", '%0.4f'%intercept_0, "," , "m =", '%0.4f'%slope_0)
    print('α - disk(Type-I)', "intercept = ", '%0.4f'%intercept_TypeI,  "," , "m =", '%0.4f'%slope_TypeI)
    print('α - disk (gw + Type-I) ', "intercept = ", '%0.4f'%intercept_gwTypeI,  "," , "m =", '%0.4f'%slope_gwTypeI)

    
    
    
ax.tick_params(axis='x', pad = 8.9)
ax.tick_params(axis='y', pad = 8.9)
# In total 3x4 lines have been plotted
lines = ax.get_lines()
legend1 = plt.legend([lines[i] for i in [0,1,2]], ["Type - I", "GW", "Type - I + GW"], title = 'Dissiptaive Force',
        title_fontsize = 23, loc = 'upper right', prop = {"size":13})
legend2 = plt.legend([lines[i] for i in [2,5,8,11]], ['$1$', r'$4.64$', 
           r'$21.45$', '$100$'], title = '$m_{2} \: \mathrm{[M_{\odot}]}$',
           title_fontsize = 27, loc = (1.02, 0.25), prop = {"size":28})

ax.add_artist(legend1)
ax.add_artist(legend2)

plt.xlabel('$m_{1} \, \mathrm{[M_{\odot}]}$', fontsize = 35, labelpad = 15)
plt.ylabel('Final merger time  [yr]', fontsize = 35, labelpad = 15)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.title(r'$ \alpha-\mathrm{disk},\, a_{i} = 500\,r_\mathrm{isco}(m = 10^{5}\, \mathrm{M_{\odot}}),\, e_{i} = 10^{-4}$', fontsize = 32, pad = 9)
plt.savefig("tm_vs_m1_α_TypeI.pdf", bbox_inches = 'tight')
#plt.grid()
plt.show()
# Out:
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2874s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/merger_system.py:198: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 4.2343s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:207: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# A termination event occurred.
#  -> Evolution took 5.0569s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2588s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.7518s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.9416s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2570s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.5135s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.8704s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2540s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.3156s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.8181s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2533s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.0890s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.7652s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2499s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.9283s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.7386s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2472s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.7766s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.3024s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2240s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.3179s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2032s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2220s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0459s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0831s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2229s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.8943s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.0452s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2180s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.7280s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9546s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2144s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.5673s
# Evolving from  176.9518499918806  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9029s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2143s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.4032s
# Evolving from  161.07894663983816  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8652s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2084s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.2467s
# Evolving from  146.6298716390381  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.8284s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2056s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 1.0840s
# Evolving from  133.4769049921472  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7773s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2040s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.9115s
# Evolving from  121.50378341829894  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7145s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2033s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.7441s
# Evolving from  110.6046726647541  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.7159s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1955s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.5857s
# Evolving from  100.68323200407426  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.6704s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1926s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.4274s
# Evolving from  91.65176264760653  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.6806s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1905s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.2921s
# Evolving from  83.43043254782773  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.6335s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1875s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1899s
# Evolving from  75.94657073733207  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.5236s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1831s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.1185s
# Evolving from  69.13402496689767  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.4734s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1849s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0776s
# Evolving from  62.932576964587255  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.4509s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1824s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0626s
# Evolving from  57.28741014717505  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.3958s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1787s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0479s
# Evolving from  52.14862507882641  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.3579s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1764s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0484s
# Evolving from  47.470798394018715  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.2493s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1696s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0496s
# Evolving from  43.212581285878045  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.1706s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1652s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0479s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.1086s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1655s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0476s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.0447s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1578s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0480s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.9652s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1587s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0482s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.9105s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1605s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0521s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.8516s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1476s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0476s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.7656s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1465s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0480s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.7039s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1403s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0473s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.6174s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1368s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0475s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.5665s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1338s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0476s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.4786s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1286s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0475s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.4141s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1246s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0333s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.3386s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1193s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0337s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.2515s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1159s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0339s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.1921s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1152s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0335s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.0972s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1062s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0335s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.0083s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1058s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0333s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.9225s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1001s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0339s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.8361s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0947s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0333s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.7851s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0925s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0337s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.6961s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0863s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0336s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.5991s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0790s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0332s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.4909s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0740s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0333s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.4001s
#
# No Accretion (GW), intercept =  44.6386 , m = -2.0001
# α - disk(Type-I) intercept =  44.8209 , m = -2.0001
# α - disk (gw + Type-I)  intercept =  25.2740 , m = -0.6989
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2441s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:42: RuntimeWarning: invalid value encountered in sqrt
#   v = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:43: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = r * np.sqrt(sp.m_total(a)*a*(1.-e**2))/r**2
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:434: RuntimeWarning: invalid value encountered in sqrt
#   v_phi = np.sqrt(self.M/r)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/halo/baryonic.py:375: RuntimeWarning: invalid value encountered in double_scalars
#   return 5.4e3 * 0.1*c.g_cm2_to_invpc / (self.alpha/0.1) / (self.f_edd / 0.1 * 0.1 / self.eps) * (r/self.M)**(3./2.)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/merger_system.py:198: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:93: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:115: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/inspiral.py:117: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 5.5362s
# Evolving from  497.5476728558015  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# /home/pratibhajangra/Downloads/imripy-main/src/imripy/inspiral/forces.py:207: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# A termination event occurred.
#  -> Evolution took 4.5848s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2421s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 4.9101s
# Evolving from  452.9167400645583  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.5562s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2404s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.9386s
# Evolving from  412.28928326262667  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.5063s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2365s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.5164s
# Evolving from  375.30618335939994  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.4686s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2370s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.2865s
# Evolving from  341.6405349010134  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.4493s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2332s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 3.0342s
# Evolving from  310.9947564484417  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.3522s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2275s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.8550s
# Evolving from  283.0979601599333  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.3193s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2242s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.6939s
# Evolving from  257.7035573267039  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2642s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2252s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.5276s
# Evolving from  234.58707869643197  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.2075s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2184s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.3276s
# Evolving from  213.54419031771602  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 4.1134s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.2203s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 2.0202s
# Evolving from  194.38888736689185  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.9723s
# ...
#  -> Evolution took 0.1317s
# Evolving from  39.33633401084537  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.0493s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1630s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0899s
# Evolving from  35.807793178938496  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 3.0073s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1588s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0612s
# Evolving from  32.59576888868492  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.9674s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1550s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0475s
# Evolving from  29.671869029602647  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.9257s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1514s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0476s
# Evolving from  27.01024831525032  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.7943s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1487s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0480s
# Evolving from  24.587379828470965  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.7429s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1416s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0479s
# Evolving from  22.381847059442592  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.6892s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1396s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0471s
# Evolving from  20.37415459829551  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.6047s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1379s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0477s
# Evolving from  18.546555808945975  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.5471s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1334s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0495s
# Evolving from  16.882895960901607  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.4621s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1299s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0478s
# Evolving from  15.36846943242917  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.4029s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1251s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0485s
# Evolving from  13.989889722858658  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.3225s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1215s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0477s
# Evolving from  12.734971125020564  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.2404s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1165s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0475s
# Evolving from  11.592621011880848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.1803s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1121s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0472s
# Evolving from  10.552741785261377  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.0940s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1094s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0477s
# Evolving from  9.60614161993842  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 2.0055s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.1031s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0475s
# Evolving from  8.74445321415848  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.9215s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0998s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0335s
# Evolving from  7.960059828380561  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.8281s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0969s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0335s
# Evolving from  7.246027958478337  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.7821s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0898s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0333s
# Evolving from  6.596046048278463  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.6897s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0852s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0335s
# Evolving from  6.004368699696058  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.6098s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0823s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0346s
# Evolving from  5.465765887322638  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, GasInteraction, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.4908s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 0.0750s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, }, accuracy = 1.0e-10
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0332s
# Evolving from  4.975476728558016  to  1.0 r_isco  with initial eccentricity 0.0001  with  Options: dissipative Forces emplyed {GasInteraction, GWLoss, }, accuracy = 1.0e-10
# A termination event occurred.
#  -> Evolution took 1.4035s
#
# No Accretion (GW), intercept =  40.0309 , m = -2.0000
# α - disk(Type-I) intercept =  40.2132 , m = -2.0000
# α - disk (gw + Type-I)  intercept =  9.8574 , m = 0.0103
